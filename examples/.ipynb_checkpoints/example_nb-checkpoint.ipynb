# %%
import numpy as np
import yt
import yt.extensions.geotiff
from IPython.display import Image

# %%
filename = 'example.tif'
ds = yt.load(filename)
# Out:
# yt : [WARNING  ] 2020-05-27 10:32:14,454 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [WARNING  ] 2020-05-27 10:32:14,455 Overriding code units: Use this option only if you know that the dataset doesn't define the units correctly or at all.
# yt : [INFO     ] 2020-05-27 10:32:14,476 Parameters: current_time              = 0.0
# yt : [INFO     ] 2020-05-27 10:32:14,476 Parameters: domain_dimensions         = [7951 7821    1]
# yt : [INFO     ] 2020-05-27 10:32:14,477 Parameters: domain_left_edge          = [0. 0. 0.] m
# yt : [INFO     ] 2020-05-27 10:32:14,479 Parameters: domain_right_edge         = [2.38545e+05 2.34645e+05 1.00000e+00] m
# yt : [ERROR    ] 2020-05-27 10:32:14,481 Missing cosmological_simulation in parameter file definition!

# %%
print(ds.field_list)
print(ds.parameters)
ds.print_stats()

slc = yt.SlicePlot(ds, 'z', '1')
# slc.save()
# Out:
# [('bands', '1')]
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 7821, 'height': 7951, 'count': 1, 'crs': CRS.from_epsg(32611), 'transform': Affine(30.0, 0.0, 204285.0,
#        0.0, -30.0, 4268115.0), 'cosmological_simulation': False}
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     1	      62184771	           397
# ----------------------------------------------
#    	     1	      62184771
#
#
# t = 0.00000000e+00 = 0.00000000e+00 s = 0.00000000e+00 years
#
# Smallest Cell:
# 	Width: 9.723e-22 Mpc
# 	Width: 9.723e-16 pc
# 	Width: 2.006e-10 AU
# 	Width: 3.000e+03 cm
# <generator object GridIndex._chunk_io at 0x1265c1d60>
# [<yt.geometry.geometry_handler.YTDataChunk object at 0x1267e08e0>]
# yt : [INFO     ] 2020-05-25 08:43:04,996 xlim = 0.000000 238545.000000
# yt : [INFO     ] 2020-05-25 08:43:04,997 ylim = 0.000000 234645.000000
# yt : [INFO     ] 2020-05-25 08:43:04,999 xlim = 0.000000 238545.000000
# yt : [INFO     ] 2020-05-25 08:43:04,999 ylim = 0.000000 234645.000000
# yt : [INFO     ] 2020-05-25 08:43:05,007 Making a fixed resolution buffer of (('bands', '1')) 800 by 800

# %%
image = slc.save()[0]
Image(filename=image)
# Out:
# yt : [INFO     ] 2020-05-25 08:43:44,259 Saving plot example.tif_Slice_z_1.png

# %%
ad = ds.all_data()

# %%
yt.ProfilePlot(ad, "x", ('bands', '1'), weight_field=None)
# Out:
# <generator object GridIndex._chunk_io at 0x1299bc890>
# [<yt.geometry.geometry_handler.YTDataChunk object at 0x12c2d5880>]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
sp = ds.sphere([150000, 150000, 0], (100, 'km'))

# %%
len(sp[('bands', '1')])
# Out:
# <generator object GridIndex._chunk_io at 0x12a54c9e0>
# [<yt.geometry.geometry_handler.YTDataChunk object at 0x12c16ea90>]
# 32872978

# %%
yt.ProfilePlot(sp, "x", ('bands', '1'), weight_field="dy")
# Out:
# <generator object GridIndex._chunk_io at 0x1299bc3c0>
# [<yt.geometry.geometry_handler.YTDataChunk object at 0x12a946a30>]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
sp = ds.sphere(ds.domain_center, ds.domain_width[0]/4)
p = yt.SlicePlot(ds, 'z', '1', data_source=sp)
# Out:
# <generator object GridIndex._chunk_io at 0x10b2b6f90>
# [<yt.geometry.geometry_handler.YTDataChunk object at 0x1221f11c0>]
# yt : [INFO     ] 2020-05-27 10:32:21,589 xlim = 0.000000 238545.000000
# yt : [INFO     ] 2020-05-27 10:32:21,590 ylim = 0.000000 234645.000000
# yt : [INFO     ] 2020-05-27 10:32:21,592 xlim = 0.000000 238545.000000
# yt : [INFO     ] 2020-05-27 10:32:21,593 ylim = 0.000000 234645.000000
# yt : [INFO     ] 2020-05-27 10:32:21,601 Making a fixed resolution buffer of (('bands', '1')) 800 by 800

# %%
p.zoom(4)
# Out:
# yt : [INFO     ] 2020-05-27 11:03:35,600 Making a fixed resolution buffer of (('bands', '1')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
